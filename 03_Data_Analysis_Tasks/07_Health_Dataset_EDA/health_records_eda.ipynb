# %% [markdown]
# # Health & Medical Records Dataset - Exploratory Data Analysis
#
# This notebook demonstrates exploratory data analysis (EDA), data inspection, missing value detection, and statistical summaries on healthcare records (`Health.csv`).

# %% [markdown]
# ### 1. Import Data Science Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Load Dataset (`Health.csv`)

# %%
data = pd.read_csv('Health.csv')
df = pd.DataFrame(data)
df.head()

# %% [markdown]
# ### 3. Data Inspection & Structural Audit

# %% [markdown]
# #### 3.1 Display Column Headers

# %%
print('Column Names:', list(df.columns))

# %% [markdown]
# #### 3.2 Dataset Dimensions & Total Size

# %%
print('Shape (rows, cols):', df.shape)
print('Total Size (elements):', df.size)

# %% [markdown]
# #### 3.3 Data Types & Info

# %%
df.info()

# %% [markdown]
# #### 3.4 Summary Statistics

# %%
df.describe()

# %% [markdown]
# #### 3.5 Missing Values Check

# %%
print('Missing Values per Column:\n', df.isna().sum())
