# %% [markdown]
# # Student Attendance & Performance Dataset - Exploratory Data Analysis
#
# This notebook demonstrates dataset creation, feature engineering, and statistical analysis on student study hours, attendance percentage, and exam results.

# %% [markdown]
# ### 1. Import Pandas & NumPy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Create Student DataFrame

# %%
data = {
    'Student': ['A', 'B', 'C', 'D', 'E', 'F'],
    'Hours': [1, 2, 3, 5, 6, 7],
    'Attendance': [50, 55, 60, 75, 80, 90],
    'Result': ['Fail', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass']
}
df = pd.DataFrame(data)
df

# %% [markdown]
# ### 3. Inspect Data & Summary Statistics

# %%
print('Shape:', df.shape)
print('\nResult Distribution:\n', df['Result'].value_counts())
display(df.describe())
