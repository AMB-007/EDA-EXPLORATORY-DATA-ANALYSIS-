# %% [markdown]
# # Loan Eligibility & Financial Risk Dataset - Exploratory Data Analysis
#
# This notebook demonstrates data cleaning, missing value detection, column inspection, and summary statistics on financial loan records (`loan.csv`).

# %% [markdown]
# ### 1. Import Data Science Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Load Dataset (`loan.csv`)

# %%
data = pd.read_csv('loan.csv')
df = pd.DataFrame(data)
df.head()

# %% [markdown]
# ### 3. Data Structural Inspection

# %% [markdown]
# #### 3.1 Column Headers

# %%
print('Columns:', list(df.columns))

# %% [markdown]
# #### 3.2 Shape & Dimensions

# %%
print('Dataset Shape (rows, cols):', df.shape)

# %% [markdown]
# #### 3.3 Summary Statistics

# %%
df.describe()

# %% [markdown]
# #### 3.4 Data Types & Info

# %%
df.info()

# %% [markdown]
# #### 3.5 Null Values Check

# %%
print('Missing Values per Column:\n', df.isna().sum())
