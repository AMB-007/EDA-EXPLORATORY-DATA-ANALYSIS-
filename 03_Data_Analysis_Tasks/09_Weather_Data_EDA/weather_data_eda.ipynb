# %% [markdown]
# # Weather Conditions & Meteorology Dataset - Exploratory Data Analysis
#
# This notebook demonstrates exploratory data analysis, structural inspection, null value checks, and target classification separation on weather condition data (`weather.csv`).

# %% [markdown]
# ### 1. Import Data Science Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Load Dataset (`weather.csv`)

# %%
data = pd.read_csv('weather.csv')
df = pd.DataFrame(data)
df.head()

# %% [markdown]
# ### 3. Data Structural Inspection

# %% [markdown]
# #### 3.1 Column Names & Shape

# %%
print('Columns:', list(df.columns))
print('Shape:', df.shape)

# %% [markdown]
# #### 3.2 Dataset Info & Types

# %%
df.info()

# %% [markdown]
# #### 3.3 Summary Statistics

# %%
df.describe()

# %% [markdown]
# #### 3.4 Check Missing Values

# %%
print('Null Values:\n', df.isna().sum())

# %% [markdown]
# ### 4. Separate Features Matrix (X) & Target Vector (y)

# %%
X = df.drop('Weather Type', axis=1)
y = df['Weather Type']
print('Features Shape:', X.shape)
print('Target Shape:', y.shape)
print('\nTarget Value Counts:\n', y.value_counts())
